# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('SALES.csv')

# %%
df1.describe()
# Out:
#        Child Material Code  Customer Code Unique
# count         4.396218e+06          4.396218e+06
# mean          1.613947e+05          1.536221e+04
# std           2.191641e+04          7.293808e+03
# min           1.504360e+05          1.031000e+03
# 25%           1.610170e+05          8.633000e+03
# 50%           1.610660e+05          1.767400e+04
# 75%           1.610860e+05          2.175700e+04
# max           1.004447e+06          2.911200e+04

# %%
read_file = pd.read_csv(r'Customer.txt')
read_file.to_csv (r'Customer.csv', index=None)

# %%
read_file = pd.read_csv(r'Materialdot.txt')
read_file.to_csv(r'Material.csv', index=None)

# %%
read_file = pd.read_csv(r'ParentChild.txt')
read_file.to_csv(r'ParentChild.csv', index=None)

# %%
df2 = pd.read_csv('Customer.csv', sep = '|')
df3 = pd.read_csv('Material.csv', sep = '|')
df4 = pd.read_csv('ParentChild.csv', sep = '|')
df2
# Out:
#        Customer Code Unique Volume Segment  Preferential Segment       City  \
# 0                      1905              D                     1   City 890
# 1                      1906              D                     1   City 994
# 2                      1907              D                     1   City 654
# 3                      1908              D                     1  City 1052
# 4                      1910              D                     1  City 1116
# ...                     ...            ...                   ...        ...
# 26406                 27387              B                     1   City 834
# 26407                 27521              B                     1   City 971
# 26408                 27622              D                     1   City 834
# 26409                 27660              D                     1   City 834
# 26410                 27377              D                     2   City 834
#
# ...

# %%
len(df2['Customer Code Unique'].unique())
# Out:
# 26411

# %%
df3['Parent Material Code'].unique()
# Out:
# array([ 150437,  150438,  150439,  150661,  151053,  151054,  151295,
#         151300,  151401,  151534,  151535,  151650,  151854,  151855,
#         151856,  151857,  151861,  151862,  151883,  151894,  151980,
#         152762,  161000,  161001,  161003,  161004,  161005,  161006,
#         161007,  161008,  161009,  161011,  161012,  161013,  161014,
#         161015,  161016,  161017,  161018,  161020,  161021,  161022,
#         161023,  161024,  161025,  161026,  161027,  161028,  161029,
#         161043,  161044,  161052,  161054,  161055,  161056,  161057,
#         161058,  161059,  161060,  161061,  161062,  161063,  161064,
#         161065,  161066,  161068,  161069,  161070,  161071,  161072,
#         161075,  161076,  161079,  161081,  161082,  161083,  161084,
#         161085,  161088,  161089,  161090,  161091,  161093,  161094,
#         161095,  161096,  161097,  161109,  161112,  161114,  161115,
# ...

# %%
df4.rename(columns = {'CHILD':'Child Material Code'}, inplace = True)

# %%
result_df = pd.merge(df1, df4, on='Child Material Code', how='left')
df14 = pd.DataFrame(result_df)
# Print the result
df14
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 0                    1000049                 11996  2022-04-12 00:00:00.000
# 1                    1000049                  1559  2022-04-12 00:00:00.000
# 2                    1000049                 20772  2022-04-12 00:00:00.000
# 3                    1000049                  4068  2022-04-12 00:00:00.000
# 4                    1000049                  5650  2022-04-12 00:00:00.000
# ...                      ...                   ...                      ...
# 4396213               161204                  9806  2023-06-08 00:00:00.000
# 4396214               161204                  9806  2023-06-13 00:00:00.000
# 4396215               161204                  9806  2023-06-20 00:00:00.000
# 4396216               161204                  9806  2023-06-24 00:00:00.000
# 4396217               161204                  9806  2023-07-01 00:00:00.000
#
#         Sales Liter   PARENT
# ...

# %%
result_df = pd.merge(df14, df2, on='Customer Code Unique', how='left')
df142 = pd.DataFrame(result_df)
# Print the result
df142
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 0                    1000049                 11996  2022-04-12 00:00:00.000
# 1                    1000049                  1559  2022-04-12 00:00:00.000
# 2                    1000049                 20772  2022-04-12 00:00:00.000
# 3                    1000049                  4068  2022-04-12 00:00:00.000
# 4                    1000049                  5650  2022-04-12 00:00:00.000
# ...                      ...                   ...                      ...
# 4396213               161204                  9806  2023-06-08 00:00:00.000
# 4396214               161204                  9806  2023-06-13 00:00:00.000
# 4396215               161204                  9806  2023-06-20 00:00:00.000
# 4396216               161204                  9806  2023-06-24 00:00:00.000
# 4396217               161204                  9806  2023-07-01 00:00:00.000
#
# ...

# %%
df142.rename(columns = {'PARENT':'Parent Material Code'}, inplace = True)

# %%
result_df = pd.merge(df142, df3, on='Parent Material Code', how='left')
df1423 = pd.DataFrame(result_df)
# Print the result
df1423
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 0                    1000049                 11996  2022-04-12 00:00:00.000
# 1                    1000049                  1559  2022-04-12 00:00:00.000
# 2                    1000049                 20772  2022-04-12 00:00:00.000
# 3                    1000049                  4068  2022-04-12 00:00:00.000
# 4                    1000049                  5650  2022-04-12 00:00:00.000
# ...                      ...                   ...                      ...
# 4396213               161204                  9806  2023-06-08 00:00:00.000
# 4396214               161204                  9806  2023-06-13 00:00:00.000
# 4396215               161204                  9806  2023-06-20 00:00:00.000
# 4396216               161204                  9806  2023-06-24 00:00:00.000
# 4396217               161204                  9806  2023-07-01 00:00:00.000
#
# ...

# %%
df1423['Sales Liter'] = df1423['Sales Liter'].str.replace(',', '.')
df1423['Sales Liter'] = df1423['Sales Liter'].astype(float)
df1423['nr_unit'] = df1423['Sales Liter']/df1423['Unit Volume']
df1423
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 0                    1000049                 11996  2022-04-12 00:00:00.000
# 1                    1000049                  1559  2022-04-12 00:00:00.000
# 2                    1000049                 20772  2022-04-12 00:00:00.000
# 3                    1000049                  4068  2022-04-12 00:00:00.000
# 4                    1000049                  5650  2022-04-12 00:00:00.000
# ...                      ...                   ...                      ...
# 4396213               161204                  9806  2023-06-08 00:00:00.000
# 4396214               161204                  9806  2023-06-13 00:00:00.000
# 4396215               161204                  9806  2023-06-20 00:00:00.000
# 4396216               161204                  9806  2023-06-24 00:00:00.000
# 4396217               161204                  9806  2023-07-01 00:00:00.000
#
# ...

# %%
len(df1423['Customer Code Unique'].unique())
# Out:
# 10536

# %%
df1423.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4396218 entries, 0 to 4396217
# Data columns (total 20 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Child Material Code   int64
#  1   Customer Code Unique  int64
#  2   Invoice_Date          object
#  3   Sales Liter           float64
#  4   Parent Material Code  int64
#  5   Volume Segment        object
#  6   Preferential Segment  int64
#  7   City                  object
#  8   Region                object
#  9   SR Tracking Code      int64
#  10  Channel               object
#  11  Location type         object
#  12  Material Group Code   int64
#  13  Imported Material     object
#  14  Alco Group Code       int64
#  15  Unit Volume           float64
#  16  Material Type         object
#  17  Package Type          object
#  18  Price Segment         object
#  19  nr_unit               float64
# dtypes: float64(3), int64(7), object(10)
# memory usage: 670.8+ MB

# %%
df1423['Volume Segment'].unique()
# Out:
# array(['D', 'A', 'C', 'B'], dtype=object)

# %%
import statistics
from statistics import mode

def most_common(df, column_name):
    return df[column_name].mode().values[0]

result = most_common(df1423, 'Customer Code Unique')
print(result)
# Out:
# 16915

# %%
filtered_df1 = df1423[df1423['Customer Code Unique'] == 16915]

# %%
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
filtered_df1['Volume Segment'].unique()
filtered_df1 = filtered_df1.drop(['Volume Segment'], axis = 1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
filtered_df1['Preferential Segment'].unique()

filtered_df1 = filtered_df1.drop(['Preferential Segment'], axis = 1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
filtered_df1['Region'].unique()
filtered_df1 = filtered_df1.drop(['Region'], axis = 1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
filtered_df1 = filtered_df1.drop(['City'], axis = 1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
filtered_df1['Location type'].unique()
filtered_df1 = filtered_df1.drop(['Location type'], axis = 1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
filtered_df1 = filtered_df1.drop(['SR Tracking Code'], axis = 1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
filtered_df1['Channel'].unique()
filtered_df1 = filtered_df1.drop(['Channel'], axis = 1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
filtered_df1 = filtered_df1.drop(['Sales Liter'], axis = 1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique             Invoice_Date  \
# 27742                 150437                 16915  2023-04-04 00:00:00.000
# 27743                 150437                 16915  2023-04-21 00:00:00.000
# 27744                 150437                 16915  2023-04-28 00:00:00.000
# 27745                 150437                 16915  2023-05-02 00:00:00.000
# 27746                 150437                 16915  2023-05-05 00:00:00.000
# ...                      ...                   ...                      ...
# 4383472               161187                 16915  2023-06-09 00:00:00.000
# 4383473               161187                 16915  2023-06-16 00:00:00.000
# 4383474               161187                 16915  2023-06-20 00:00:00.000
# 4383475               161187                 16915  2023-06-27 00:00:00.000
# 4383476               161187                 16915  2023-06-30 00:00:00.000
#
# ...

# %%
import datetime as dt
import category_encoders as ce

filtered_df1['Invoice_Date'] = pd.to_datetime(filtered_df1['Invoice_Date'])
filtered_df1['Day_of_Week'] =filtered_df1['Invoice_Date'].dt.strftime('%A')

encoder = ce.BinaryEncoder(cols=['Day_of_Week'], return_df = True)
filtered_df1 = encoder.fit_transform(filtered_df1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique Invoice_Date  \
# 27742                 150437                 16915   2023-04-04
# 27743                 150437                 16915   2023-04-21
# 27744                 150437                 16915   2023-04-28
# 27745                 150437                 16915   2023-05-02
# 27746                 150437                 16915   2023-05-05
# ...                      ...                   ...          ...
# 4383472               161187                 16915   2023-06-09
# 4383473               161187                 16915   2023-06-16
# 4383474               161187                 16915   2023-06-20
# 4383475               161187                 16915   2023-06-27
# 4383476               161187                 16915   2023-06-30
#
#          Parent Material Code  Material Group Code Imported Material  \
# 27742                  150437                25139                No
# ...

# %%
filtered_df1['Month'] = filtered_df1['Invoice_Date'].dt.month
filtered_df1['Day'] = filtered_df1['Invoice_Date'].dt.day
filtered_df1['Year'] = filtered_df1['Invoice_Date'].dt.year
filtered_df1['Year'] = filtered_df1['Year'].map({2022 : 0, 2023 : 1})
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique Invoice_Date  \
# 27742                 150437                 16915   2023-04-04
# 27743                 150437                 16915   2023-04-21
# 27744                 150437                 16915   2023-04-28
# 27745                 150437                 16915   2023-05-02
# 27746                 150437                 16915   2023-05-05
# ...                      ...                   ...          ...
# 4383472               161187                 16915   2023-06-09
# 4383473               161187                 16915   2023-06-16
# 4383474               161187                 16915   2023-06-20
# 4383475               161187                 16915   2023-06-27
# 4383476               161187                 16915   2023-06-30
#
#          Parent Material Code  Material Group Code Imported Material  \
# 27742                  150437                25139                No
# ...

# %%
encoder = ce.BinaryEncoder(cols=['Month','Day'], return_df = True)
filtered_df1 = encoder.fit_transform(filtered_df1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique Invoice_Date  \
# 27742                 150437                 16915   2023-04-04
# 27743                 150437                 16915   2023-04-21
# 27744                 150437                 16915   2023-04-28
# 27745                 150437                 16915   2023-05-02
# 27746                 150437                 16915   2023-05-05
# ...                      ...                   ...          ...
# 4383472               161187                 16915   2023-06-09
# 4383473               161187                 16915   2023-06-16
# 4383474               161187                 16915   2023-06-20
# 4383475               161187                 16915   2023-06-27
# 4383476               161187                 16915   2023-06-30
#
#          Parent Material Code  Material Group Code Imported Material  \
# 27742                  150437                25139                No
# ...

# %%
filtered_df1 = filtered_df1.drop(['Invoice_Date'], axis = 1)
filtered_df1
# Out:
#          Child Material Code  Customer Code Unique  Parent Material Code  \
# 27742                 150437                 16915                150437
# 27743                 150437                 16915                150437
# 27744                 150437                 16915                150437
# 27745                 150437                 16915                150437
# 27746                 150437                 16915                150437
# ...                      ...                   ...                   ...
# 4383472               161187                 16915                161187
# 4383473               161187                 16915                161187
# 4383474               161187                 16915                161187
# 4383475               161187                 16915                161187
# 4383476               161187                 16915                161187
#
#          Material Group Code Imported Material  Alco Group Code  Unit Volume  \
# ...

# %%
encoder = ce.BinaryEncoder(cols=['Child Material Code'], return_df = True)
filtered_df1 = encoder.fit_transform(filtered_df1)
filtered_df1
# Out:
#          Child Material Code_0  Child Material Code_1  Child Material Code_2  \
# 27742                        0                      0                      0
# 27743                        0                      0                      0
# 27744                        0                      0                      0
# 27745                        0                      0                      0
# 27746                        0                      0                      0
# ...                        ...                    ...                    ...
# 4383472                      1                      0                      1
# 4383473                      1                      0                      1
# 4383474                      1                      0                      1
# 4383475                      1                      0                      1
# 4383476                      1                      0                      1
#
# ...

# %%
encoder = ce.BinaryEncoder(cols=['Parent Material Code'], return_df = True)
filtered_df1 = encoder.fit_transform(filtered_df1)
filtered_df1
# Out:
#          Child Material Code_0  Child Material Code_1  Child Material Code_2  \
# 27742                        0                      0                      0
# 27743                        0                      0                      0
# 27744                        0                      0                      0
# 27745                        0                      0                      0
# 27746                        0                      0                      0
# ...                        ...                    ...                    ...
# 4383472                      1                      0                      1
# 4383473                      1                      0                      1
# 4383474                      1                      0                      1
# 4383475                      1                      0                      1
# 4383476                      1                      0                      1
#
# ...

# %%
filtered_df1.columns
# Out:
# Index(['Child Material Code_0', 'Child Material Code_1',
#        'Child Material Code_2', 'Child Material Code_3',
#        'Child Material Code_4', 'Child Material Code_5',
#        'Child Material Code_6', 'Customer Code Unique',
#        'Parent Material Code_0', 'Parent Material Code_1',
#        'Parent Material Code_2', 'Parent Material Code_3',
#        'Parent Material Code_4', 'Parent Material Code_5',
#        'Parent Material Code_6', 'Material Group Code', 'Imported Material',
#        'Alco Group Code', 'Unit Volume', 'Material Type', 'Package Type',
#        'Price Segment', 'nr_unit', 'Day_of_Week_0', 'Day_of_Week_1',
#        'Day_of_Week_2', 'Month_0', 'Month_1', 'Month_2', 'Month_3', 'Day_0',
#        'Day_1', 'Day_2', 'Day_3', 'Day_4', 'Year'],
#       dtype='object')

# %%
encoder = ce.BinaryEncoder(cols=['Material Group Code'], return_df = True)
filtered_df1 = encoder.fit_transform(filtered_df1)
filtered_df1
# Out:
#          Child Material Code_0  Child Material Code_1  Child Material Code_2  \
# 27742                        0                      0                      0
# 27743                        0                      0                      0
# 27744                        0                      0                      0
# 27745                        0                      0                      0
# 27746                        0                      0                      0
# ...                        ...                    ...                    ...
# 4383472                      1                      0                      1
# 4383473                      1                      0                      1
# 4383474                      1                      0                      1
# 4383475                      1                      0                      1
# 4383476                      1                      0                      1
#
# ...

# %%
filtered_df1['Imported Material'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
filtered_df1['Imported Material'] = filtered_df1['Imported Material'].map({'No' : 0, 'Yes' : 1})

# %%
filtered_df1['Alco Group Code'] = filtered_df1['Alco Group Code'].map({1 : 0, 2 : 1})

# %%
encoder = ce.BinaryEncoder(cols=['Unit Volume'], return_df = True)
filtered_df1 = encoder.fit_transform(filtered_df1)
filtered_df1
# Out:
#          Child Material Code_0  Child Material Code_1  Child Material Code_2  \
# 27742                        0                      0                      0
# 27743                        0                      0                      0
# 27744                        0                      0                      0
# 27745                        0                      0                      0
# 27746                        0                      0                      0
# ...                        ...                    ...                    ...
# 4383472                      1                      0                      1
# 4383473                      1                      0                      1
# 4383474                      1                      0                      1
# 4383475                      1                      0                      1
# 4383476                      1                      0                      1
#
# ...

# %%
encoder = ce.BinaryEncoder(cols=['Package Type'], return_df = True)
filtered_df1 = encoder.fit_transform(filtered_df1)
filtered_df1
# Out:
#          Child Material Code_0  Child Material Code_1  Child Material Code_2  \
# 27742                        0                      0                      0
# 27743                        0                      0                      0
# 27744                        0                      0                      0
# 27745                        0                      0                      0
# 27746                        0                      0                      0
# ...                        ...                    ...                    ...
# 4383472                      1                      0                      1
# 4383473                      1                      0                      1
# 4383474                      1                      0                      1
# 4383475                      1                      0                      1
# 4383476                      1                      0                      1
#
# ...

# %%
encoder = ce.BinaryEncoder(cols=['Price Segment'], return_df = True)
filtered_df1 = encoder.fit_transform(filtered_df1)
filtered_df1
# Out:
#          Child Material Code_0  Child Material Code_1  Child Material Code_2  \
# 27742                        0                      0                      0
# 27743                        0                      0                      0
# 27744                        0                      0                      0
# 27745                        0                      0                      0
# 27746                        0                      0                      0
# ...                        ...                    ...                    ...
# 4383472                      1                      0                      1
# 4383473                      1                      0                      1
# 4383474                      1                      0                      1
# 4383475                      1                      0                      1
# 4383476                      1                      0                      1
#
# ...

# %%
filtered_df1['Material Type'].unique()
encoder = ce.BinaryEncoder(cols=['Material Type'], return_df = True)
filtered_df1 = encoder.fit_transform(filtered_df1)
filtered_df1
# Out:
#          Child Material Code_0  Child Material Code_1  Child Material Code_2  \
# 27742                        0                      0                      0
# 27743                        0                      0                      0
# 27744                        0                      0                      0
# 27745                        0                      0                      0
# 27746                        0                      0                      0
# ...                        ...                    ...                    ...
# 4383472                      1                      0                      1
# 4383473                      1                      0                      1
# 4383474                      1                      0                      1
# 4383475                      1                      0                      1
# 4383476                      1                      0                      1
#
# ...

# %%
filtered_df1.columns
# Out:
# Index(['Child Material Code_0', 'Child Material Code_1',
#        'Child Material Code_2', 'Child Material Code_3',
#        'Child Material Code_4', 'Child Material Code_5',
#        'Child Material Code_6', 'Customer Code Unique',
#        'Parent Material Code_0', 'Parent Material Code_1',
#        'Parent Material Code_2', 'Parent Material Code_3',
#        'Parent Material Code_4', 'Parent Material Code_5',
#        'Parent Material Code_6', 'Material Group Code_0',
#        'Material Group Code_1', 'Material Group Code_2',
#        'Material Group Code_3', 'Material Group Code_4',
#        'Material Group Code_5', 'Imported Material', 'Alco Group Code',
#        'Unit Volume_0', 'Unit Volume_1', 'Unit Volume_2', 'Unit Volume_3',
#        'Material Type_0', 'Material Type_1', 'Material Type_2',
#        'Package Type_0', 'Package Type_1', 'Price Segment_0',
#        'Price Segment_1', 'Price Segment_2', 'nr_unit', 'Day_of_Week_0',
# ...

# %%
filtered_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4635 entries, 27742 to 4383476
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Child Material Code_0   4635 non-null   int64
#  1   Child Material Code_1   4635 non-null   int64
#  2   Child Material Code_2   4635 non-null   int64
#  3   Child Material Code_3   4635 non-null   int64
#  4   Child Material Code_4   4635 non-null   int64
#  5   Child Material Code_5   4635 non-null   int64
#  6   Child Material Code_6   4635 non-null   int64
#  7   Customer Code Unique    4635 non-null   int64
#  8   Parent Material Code_0  4635 non-null   int64
#  9   Parent Material Code_1  4635 non-null   int64
#  10  Parent Material Code_2  4635 non-null   int64
#  11  Parent Material Code_3  4635 non-null   int64
#  12  Parent Material Code_4  4635 non-null   int64
#  13  Parent Material Code_5  4635 non-null   int64
# ...

# %%
from sklearn.ensemble import IsolationForest
def get_IsolationForest(df, target):
    df_IsolationForest = filtered_df1.copy()
    model=IsolationForest()
    # Apply algorithm to data
    df_IsolationForest['outlier']=pd.Series(model.fit_predict(df_IsolationForest.values))
    # Remove rows where there is -1 in created column
    df_IsolationForest=df_IsolationForest[df_IsolationForest.outlier!=-1]
    # Drop created column
    df_IsolationForest.drop(['outlier'], axis=1, inplace=True)
    return df_IsolationForest

df_IsolationForest = get_IsolationForest(filtered_df1,'nr_unit')
df_IsolationForest
# Out:
#          Child Material Code_0  Child Material Code_1  Child Material Code_2  \
# 27742                        0                      0                      0
# 27743                        0                      0                      0
# 27744                        0                      0                      0
# 27745                        0                      0                      0
# 27746                        0                      0                      0
# ...                        ...                    ...                    ...
# 4383472                      1                      0                      1
# 4383473                      1                      0                      1
# 4383474                      1                      0                      1
# 4383475                      1                      0                      1
# 4383476                      1                      0                      1
#
# ...

# %%
filtered_df1 = filtered_df1.drop(['Customer Code Unique'], axis = 1)

# %%
from sklearn.decomposition import PCA


def PCA_2(df,n_comp,target):
    X = df.drop(target, axis = 1)
    Y = df[target]
    pca = PCA(n_components=n_comp)
    pca.fit(X)
    pca_df = pca.transform(X)
    pca_df = pd.DataFrame(pca_df)
    pca_df[target] = Y
    return pca_df

pca_df = PCA_2(filtered_df1,20,'nr_unit')

# %%
pca_df['nr_unit'] = filtered_df1['nr_unit'].values
pca_df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.057595 -0.543605  0.249558 -0.899789 -0.213751 -0.527745 -1.294925
# 1     0.092563 -0.650881  0.536805 -1.052997  0.824029 -0.371379 -1.071253
# 2     0.089505 -0.653591  0.557562 -1.061712  0.866292 -0.366986 -1.061339
# 3     0.048858 -0.519836  0.236857 -0.921515 -0.255507 -0.532939 -1.313776
# 4     0.070924 -0.610430  0.547731 -1.083226  0.835385 -0.365015 -1.048182
# ...        ...       ...       ...       ...       ...       ...       ...
# 4630  0.420346 -0.668412  0.097292 -0.849566  1.073310  0.397731 -0.311158
# 4631  0.430548 -0.695314  0.083613 -0.840377  1.020121  0.378282 -0.335267
# 4632  0.402008 -0.602630 -0.174938 -0.705499  0.056096  0.231426 -0.588931
# 4633  0.395128 -0.539537 -0.293988 -0.655446 -0.313484  0.186615 -0.621637
# 4634  0.434104 -0.694595  0.127952 -0.866924  1.105068  0.397596 -0.366950
#
# ...

# %%
filtered_df1.isnull().sum()
# Out:
# Child Material Code_0     0
# Child Material Code_1     0
# Child Material Code_2     0
# Child Material Code_3     0
# Child Material Code_4     0
# Child Material Code_5     0
# Child Material Code_6     0
# Parent Material Code_0    0
# Parent Material Code_1    0
# Parent Material Code_2    0
# Parent Material Code_3    0
# Parent Material Code_4    0
# Parent Material Code_5    0
# Parent Material Code_6    0
# Material Group Code_0     0
# Material Group Code_1     0
# Material Group Code_2     0
# Material Group Code_3     0
# Material Group Code_4     0
# Material Group Code_5     0
# Imported Material         0
# Alco Group Code           0
# Unit Volume_0             0
# Unit Volume_1             0
# Unit Volume_2             0
# Unit Volume_3             0
# Material Type_0           0
# Material Type_1           0
# Material Type_2           0
# Package Type_0            0
# Package Type_1            0
# Price Segment_0           0
# Price Segment_1           0
# ...

# %%
from kydavra import PValueSelector

def get_PValue(df,target):
    pvalue_selector = PValueSelector()
    selected_columns = pvalue_selector.select(df,target)
    return selected_columns
    
selected_columns = get_PValue(filtered_df1,'nr_unit')
selected_columns
# Out:
# ['Child Material Code_0',
#  'Child Material Code_1',
#  'Child Material Code_2',
#  'Child Material Code_4',
#  'Child Material Code_5',
#  'Child Material Code_6',
#  'Parent Material Code_0',
#  'Parent Material Code_1',
#  'Parent Material Code_4',
#  'Parent Material Code_5',
#  'Material Group Code_1',
#  'Material Group Code_2',
#  'Material Group Code_3',
#  'Material Group Code_4',
#  'Material Group Code_5',
#  'Unit Volume_0',
#  'Unit Volume_1',
#  'Unit Volume_3',
#  'Material Type_0',
#  'Material Type_2',
#  'Package Type_0',
#  'Package Type_1',
#  'Price Segment_0',
#  'Day_of_Week_0',
#  'Month_1',
#  'Day_1']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
def apply_model(df,model):
    X = df.drop('nr_unit', axis = 1)
    Y = df['nr_unit']

    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.25, random_state = 12)
    tuned_parameters = {
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson']
    }
    clf = GridSearchCV(RandomForestRegressor(), tuned_parameters,scoring='recall')
    clf.fit(X_train, y_train)
    output69 = clf.predict(X_test)
    f1 = mean_squared_error(y_test,output69)
    f2 = mean_absolute_error(y_test,output69)
    f3 = r2_score(y_test,output69)
    print(f1,' ',f2,' ',f3)
    
def fun1(model):
    print("Simple df")
    apply_model(filtered_df1,model)
    print("PCA dataframe")
    apply_model(pca_df,model)

# %%
import warnings
warnings.filterwarnings("ignore")
fun1(RandomForestRegressor())
# Out:
# Simple df
# 1789150.185925075   586.1602572828358   0.11112799975779553
# PCA dataframe
# 1674538.4151096225   542.2260413938212   0.16806854883940225

# %%
from sklearn.linear_model import LinearRegression
X = filtered_df1.drop('nr_unit', axis = 1)
Y = filtered_df1['nr_unit']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25)
 
# Splitting the data into training and testing data
regr = LinearRegression()
 
regr.fit(X_train, y_train)
f44 = regr.predict(X_test)
print(r2_score(f44, y_test))
# Out:
# -5.329513881631636

# %%
from sklearn.linear_model import LinearRegression
X = pca_df.drop('nr_unit', axis = 1)
Y = pca_df['nr_unit']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25)
 
# Splitting the data into training and testing data
regr = LinearRegression()
 
regr.fit(X_train, y_train)
f44 = regr.predict(X_test)
print(r2_score(f44, y_test))
# Out:
# -12.145595964008715

# %%
from sklearn.neighbors import KNeighborsRegressor

neigh = KNeighborsRegressor()
neigh.fit(X_train, y_train)
f33 = neigh.predict(X_test)
print(r2_score(y_test,f33))
# Out:
# 0.054163748976263526

# %%
from sklearn.neural_network import MLPRegressor

regr = MLPRegressor(random_state=1, max_iter=500).fit(X_train, y_train)
f34 = regr.predict(X_test)
print(r2_score(y_test,f34))
# Out:
# 0.12987267666525737

# %%
from sklearn.neural_network import MLPRegressor

regr = MLPRegressor(random_state=1, max_iter=500).fit(X_train, y_train)
f34 = regr.predict(X_test)
print(r2_score(y_test,f34))
# Out:
# 0.12987267666525737

# %%
# value_counts = df1423['Customer Code Unique'].value_counts()

# %%
# value_counts

# %%
# filtered_df3 = df1423[df1423['Customer Code Unique'] == 22455]
# filtered_df3

# %%
# filtered_df2 = df1423[df1423['Customer Code Unique'] == 10203]
# filtered_df2
